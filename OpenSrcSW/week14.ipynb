# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import csv
f=open('sssseoul.csv')
data=csv.reader(f)
plt.rcParams["font.family"]="Malgun Gothic"

result1=[]
result2=[]
result3=[]
result4=[]
result5=[]
result6=[]
result7=[]
result8=[]
result9=[]
result10=[]
result11=[]
result12=[]
result13=[]
result14=[]
result15=[]
result16=[]
result17=[]
result18=[]
result19=[]
result20=[]
result21=[]
result22=[]
result23=[]
result24=[]
result25=[]
result=[]
ch=','
float1=0
float2=0
float3=0
float4=0
float5=0
float6=0
float7=0
float8=0
float9=0
float10=0
float11=0
float12=0
float13=0
float14=0
float15=0
float16=0
float17=0
float18=0
float19=0
float20=0
float21=0
float22=0
float23=0
float24=0
my='abc'
max=0
min=999999999999999999999
for row in data:
    if row[1]=='서울특별시 종로구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result5.append(int(row[i]))
            numpy5=np.asarray(result5)
    elif row[1]=='서울특별시 중구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result2.append(int(row[i]))
            numpy2=np.asarray(result2)
    elif row[1]=='서울특별시 용산구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result3.append(int(row[i]))
            numpy3=np.asarray(result3)
    elif row[1]=='서울특별시 성동구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result4.append(int(row[i]))
            numpy4=np.asarray(result4)
    elif row[1]=='서울특별시 광진구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result1.append(int(row[i]))
            numpy1=np.asarray(result1)
    elif row[1]=='서울특별시 동대문구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result6.append(int(row[i]))
            numpy6=np.asarray(result6)
    elif row[1]=='서울특별시 중랑구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result7.append(int(row[i]))
            numpy7=np.asarray(result7)
    elif row[1]=='서울특별시 성북구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result8.append(int(row[i]))
            numpy8=np.asarray(result8)
    elif row[1]=='서울특별시 강북구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result9.append(int(row[i]))
            numpy9=np.asarray(result9)
    elif row[1]=='서울특별시 도봉구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result10.append(int(row[i]))
            numpy10=np.asarray(result10)
    elif row[1]=='서울특별시 노원구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result11.append(int(row[i]))
            numpy11=np.asarray(result11)
    elif row[1]=='서울특별시 은평구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result12.append(int(row[i]))
            numpy12=np.asarray(result12)
    elif row[1]=='서울특별시 서대문구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result13.append(int(row[i]))
            numpy13=np.asarray(result13)
    elif row[1]=='서울특별시 마포구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result14.append(int(row[i]))
            numpy14=np.asarray(result14)
    elif row[1]=='서울특별시 양천구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result15.append(int(row[i]))
            numpy15=np.asarray(result15)
    elif row[1]=='서울특별시 강서구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result16.append(int(row[i]))
            numpy16=np.asarray(result16)
    elif row[1]=='서울특별시 구로구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result17.append(int(row[i]))
            numpy17=np.asarray(result17)
    elif row[1]=='서울특별시 금천구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result18.append(int(row[i]))
            numpy18=np.asarray(result18)
    elif row[1]=='서울특별시 영등포구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result19.append(int(row[i]))
            numpy19=np.asarray(result19)
    elif row[1]=='서울특별시 동작구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result20.append(int(row[i]))
            numpy20=np.asarray(result20)
    elif row[1]=='서울특별시 관악구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result21.append(int(row[i]))
            numpy21=np.asarray(result21)
    elif row[1]=='서울특별시 서초구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result22.append(int(row[i]))
            numpy22=np.asarray(result22)
    elif row[1]=='서울특별시 강남구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result23.append(int(row[i]))
            numpy23=np.asarray(result23)
    elif row[1]=='서울특별시 송파구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result24.append(int(row[i]))
            numpy24=np.asarray(result24)
    elif row[1]=='서울특별시 강동구 ':
        for i in range(4,105):
            row[i]=''.join( x for x in row[i] if x not in ch)
            result25.append(int(row[i]))
            numpy25=np.asarray(result25)
for i in np.square(numpy1-numpy2):
    float1+=i
for i in np.square(numpy1-numpy3):
    float2+=i
for i in np.square(numpy1-numpy4):
    float3+=i
for i in np.square(numpy1-numpy5):
    float4+=i
for i in np.square(numpy1-numpy6):
    float5+=i
for i in np.square(numpy1-numpy7):
    float6+=i
for i in np.square(numpy1-numpy8):
    float7+=i
for i in np.square(numpy1-numpy9):
    float8+=i
for i in np.square(numpy1-numpy10):
    float9+=i
for i in np.square(numpy1-numpy11):
    float10+=i
for i in np.square(numpy1-numpy12):
    float11+=i
for i in np.square(numpy1-numpy13):
    float12+=i
for i in np.square(numpy1-numpy14):
    float13+=i
for i in np.square(numpy1-numpy15):
    float14+=i
for i in np.square(numpy1-numpy16):
    float15+=i
for i in np.square(numpy1-numpy17):
    float16+=i
for i in np.square(numpy1-numpy18):
    float17+=i
for i in np.square(numpy1-numpy19):
    float18+=i
for i in np.square(numpy1-numpy20):
    float19+=i
for i in np.square(numpy1-numpy21):
    float20+=i
for i in np.square(numpy1-numpy22):
    float21+=i
for i in np.square(numpy1-numpy23):
    float22+=i
for i in np.square(numpy1-numpy24):
    float23+=i
for i in np.square(numpy1-numpy25):
    float24+=i
result.append(float1)
result.append(float2)
result.append(float3)
result.append(float4)
result.append(float5)
result.append(float6)
result.append(float7)
result.append(float8)
result.append(float9)
result.append(float10)
result.append(float11)
result.append(float12)
result.append(float13)
result.append(float14)
result.append(float15)
result.append(float16)
result.append(float17)
result.append(float18)
result.append(float19)
result.append(float20)
result.append(float21)
result.append(float22)
result.append(float23)
result.append(float24)
for i in result:
    if max<i:
        max=i
for i in result:
    if min>i:
        min=i

max1=str(max)
min1=str(min)
plt.style.use('ggplot')
plt.plot(numpy1,label='광진구')
plt.plot(numpy6,label='가장 비슷한 구는 동대문구이고 표준편차는'+min1+"입니다.")
plt.plot(numpy24,label='가장 다른 구는 송파구이고 표준편차는'+max1+"입니다.")
plt.legend()
plt.show()
